# %%
# importing libraries
import numpy as np 
import pandas as pd 
import re
import nltk 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !pip install -U textblob
# Out:
# Requirement already satisfied: textblob in /home/nhgirma/anaconda3/lib/python3.9/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from nltk>=3.1->textblob) (2022.3.15)
# Requirement already satisfied: joblib in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: tqdm in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from nltk>=3.1->textblob) (4.64.0)
# Requirement already satisfied: click in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from nltk>=3.1->textblob) (8.0.4)

# %%
# import necessary modules
from extract_dataframe import read_json       
from extract_dataframe import TweetDfExtractor    
from clean_tweets_dataframe import Clean_Tweets

# %%
_, tweet_list = read_json("./data/global_twitter_data.json")
tweet = TweetDfExtractor(tweet_list)
tweet_df = tweet.get_tweet_df(save=True)
# Out:
# File Successfully Saved.!!!

# %%
processed_df = pd.read_csv('processed_tweet_data.csv')
cleaner = Clean_Tweets(df=processed_df)
processed_df = cleaner.drop_unwanted_column(processed_df)
processed_df = cleaner.drop_duplicate(processed_df)
processed_df = cleaner.convert_to_datetime(processed_df)
processed_df = cleaner.convert_to_numbers(processed_df)
processed_df = cleaner.remove_non_english_tweets(processed_df)
# Out:
# Automation in Action...!!!

# %% [markdown]
# # Data Exploration

# %%
processed_df.head()
# Out:
#                  created_at  statuses_count  \
# 0 2022-08-07 22:31:20+00:00            8097
# 1 2022-08-07 22:31:16+00:00            5831
# 2 2022-08-07 22:31:07+00:00            1627
# 3 2022-08-07 22:31:06+00:00            1627
# 4 2022-08-07 22:31:04+00:00           18958
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                        original_text  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1  RT @IndoPac_Info: #China's media explains the ...
# 2  China even cut off communication, they don't a...
# 3  Putin to #XiJinping : I told you my friend, Ta...
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...
#
#                                           clean_text  sentiment      polarity  \
# 0  \n\nLets focus in one very specific zone of th...         -1  0.000000e+00
# 1   #China's media explains the military reasons ...          0 -1.000000e-01
# 2  China even cut off communication, they don't a...         -1  0.000000e+00
# 3  Putin to #XiJinping : I told you my friend, Ta...          1  1.000000e-01
# 4   I’m sorry, I thought Taiwan was an independen...          0 -6.938894e-18
#
#    subjectivity lang  favorite_count  retweet_count original_author  \
# 0       0.08125   en           15760              2       i_ameztoy
# 1       0.10000   en            6967            201           ZIisq
# 2       0.00000   en            2166              0       Fin21Free
# 3       0.35000   en            2166              0       Fin21Free
# 4       0.55625   en           17247            381  VizziniDolores
#
#    screen_count  followers_count  friends_count possibly_sensitive   hashtags  \
# 0           232            20497           2621                NaN       City
# 1             3               65            272                NaN      China
# 2             0               85            392                NaN  XiJinping
# 3             0               85            392                NaN  XiJinping
# 4             0              910           2608                NaN        NaN
#
#    user_mentions           place  place_coord_boundaries
# 0            NaN             NaN                     NaN
# 1            NaN             NaN                     NaN
# 2            NaN     Netherlands                     NaN
# 3            NaN     Netherlands                     NaN
# 4            NaN  Ayent, Schweiz                     NaN

# %%
def clean_text_cleaner(clean_text: str) -> str:
    cleaned_text = re.sub('\n', '', clean_text)
    cleaned_text = re.findall(r'[a-zA-Z]+', cleaned_text)
    cleaned_text = " ".join(cleaned_text)
    cleaned_text = re.sub(r'http.*', "", cleaned_text)

    return cleaned_text

# %%
processed_df['clean_text'] = tweet_df['clean_text'].apply(clean_text_cleaner)
processed_df['clean_text']
# Out:
# 0        Lets focus in one very specific zone of the we...
# 1        China s media explains the military reasons fo...
# 2        China even cut off communication they don t an...
# 3        Putin to XiJinping I told you my friend Taiwan...
# 4        I m sorry I thought Taiwan was an independent ...
#                                ...
# 21995    A good infographic of China s missile launches...
# 21996    A good infographic of China s missile launches...
# 21997                     Reuters Thanks Pelosi smart move
# 21998    Taiwan people s Desire for Unification With Ch...
# 21999    Taiwan people s Desire for Unification With Ch...
# Name: clean_text, Length: 22000, dtype: object

# %%
processed_df.columns
# Out:
# Index(['created_at', 'statuses_count', 'source', 'original_text', 'clean_text',
#        'sentiment', 'polarity', 'subjectivity', 'lang', 'favorite_count',
#        'retweet_count', 'original_author', 'screen_count', 'followers_count',
#        'friends_count', 'possibly_sensitive', 'hashtags', 'user_mentions',
#        'place', 'place_coord_boundaries'],
#       dtype='object')

# %%
processed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22000 entries, 0 to 21999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   created_at              22000 non-null  datetime64[ns, UTC]
#  1   statuses_count          22000 non-null  int64
#  2   source                  22000 non-null  object
#  3   original_text           22000 non-null  object
#  4   clean_text              22000 non-null  object
#  5   sentiment               22000 non-null  int64
#  6   polarity                22000 non-null  float64
#  7   subjectivity            22000 non-null  float64
#  8   lang                    22000 non-null  object
#  9   favorite_count          22000 non-null  int64
#  10  retweet_count           22000 non-null  int64
#  11  original_author         22000 non-null  object
#  12  screen_count            22000 non-null  int64
#  13  followers_count         22000 non-null  int64
#  14  friends_count           22000 non-null  int64
#  15  possibly_sensitive      6191 non-null   object
#  16  hashtags                19141 non-null  object
#  17  user_mentions           0 non-null      float64
#  18  place                   12107 non-null  object
#  19  place_coord_boundaries  0 non-null      float64
# dtypes: datetime64[ns, UTC](1), float64(4), int64(7), object(8)
# memory usage: 3.5+ MB

# %%
processed_df.shape
# Out:
# (22000, 20)

# %%
# checking for missing values
print("The number of missing value(s) based on columns:\n{}".format(processed_df.isnull().sum()))
print("The number of missing value(s): {}".format(processed_df.isnull().sum().sum()))
print("Columns having missing value(s):{}".format(processed_df.columns[processed_df.isnull().any()]))
# Out:
# The number of missing value(s) based on columns:
# created_at                    0
# statuses_count                0
# source                        0
# original_text                 0
# clean_text                    0
# sentiment                     0
# polarity                      0
# subjectivity                  0
# lang                          0
# favorite_count                0
# retweet_count                 0
# original_author               0
# screen_count                  0
# followers_count               0
# friends_count                 0
# possibly_sensitive        15809
# hashtags                   2859
# user_mentions             22000
# place                      9893
# place_coord_boundaries    22000
# dtype: int64
# The number of missing value(s): 72561
# Columns having missing value(s):Index(['possibly_sensitive', 'hashtags', 'user_mentions', 'place',
#        'place_coord_boundaries'],
#       dtype='object')

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /home/nhgirma/anaconda3/lib/python3.9/site-packages (1.8.2.2)
# Requirement already satisfied: pillow in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: six>=1.5 in /home/nhgirma/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # Importing some more libraries

# %%
import os
import sys
import inspect
from wordcloud import STOPWORDS,WordCloud
from gensim import corpora
import string

# %%
tweets_df = pd.DataFrame(columns=['original_text','clean_text','sentiment','lang','hashtags'])
#def clean_text_cleaner(clean_text: str) -> str:
 #   cleaned_text = re.sub('\n', '', clean_text)
  #  cleaned_text = re.findall(r'[a-zA-Z]+', cleaned_text)
   # cleaned_text = " ".join(cleaned_text)
    #cleaned_text = re.sub(r'http.*', "", cleaned_text)

#    return cleaned_text
#tweets_df['clean_text'] = tweet_df['clean_text'].apply(clean_text_cleaner)



tweets_df['original_text'] =  processed_df['original_text'].to_list()
tweets_df['clean_text'] =  processed_df['clean_text'].to_list()
tweets_df['sentiment'] =  processed_df['sentiment'].to_list()
tweets_df['lang'] = processed_df['lang'].to_list()
tweets_df['hashtags'] = processed_df['hashtags'].to_list()

tweets_df['clean_text']= tweets_df['clean_text'].apply(lambda x: x.translate(str.maketrans(' ', ' ', string.punctuation)))
tweets_df.head()
# Out:
#                                        original_text  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1  RT @IndoPac_Info: #China's media explains the ...
# 2  China even cut off communication, they don't a...
# 3  Putin to #XiJinping : I told you my friend, Ta...
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...
#
#                                           clean_text  sentiment lang  \
# 0  Lets focus in one very specific zone of the we...         -1   en
# 1  China s media explains the military reasons fo...          0   en
# 2  China even cut off communication they don t an...         -1   en
# 3  Putin to XiJinping I told you my friend Taiwan...          1   en
# 4  I m sorry I thought Taiwan was an independent ...          0   en
#
#     hashtags
# 0       City
# 1      China
# 2  XiJinping
# 3  XiJinping
# 4        NaN

# %%
tweets_df['hashtags'][0:5]
# Out:
# 0         City
# 1        China
# 2    XiJinping
# 3    XiJinping
# 4          NaN
# Name: hashtags, dtype: object

# %%
tweets_df = tweets_df.fillna("")
tweets_df = tweets_df.drop(['original_text'],axis=1)

# %%
tweets_df.to_csv('data_for_modeling.csv', index=False)
print('File Saved Successfully Saved.!!!')
# Out:
# File Saved Successfully Saved.!!!

# %%
tweets_df.sentiment.value_counts().plot(kind='pie')
plt.legend(['negative','positive','neutral'])

# %%
tweets_df['clean_text'] =  tweets_df['clean_text'].astype(str)
tweet_df['clean_text'] = tweet_df['clean_text'].apply(lambda x: re.sub('\n', '', x))
tweets_df['clean_text'] =  tweets_df['clean_text'].apply(lambda x: x.lower())
tweets_df['sentiment'] =  tweets_df['sentiment'].astype(int)
tweets_df['hashtags'] = tweets_df['hashtags'].astype(str)
tweets_df['hashtags'] = tweets_df['hashtags'].apply(lambda x: x.lower())
tweets_df['hashtags']= tweets_df['hashtags'].apply(lambda x: x.translate(str.maketrans(' ', ' ', string.punctuation)))

# %%
tweets_df['clean_text'][0:5]
# Out:
# 0    lets focus in one very specific zone of the we...
# 1    china s media explains the military reasons fo...
# 2    china even cut off communication they don t an...
# 3    putin to xijinping i told you my friend taiwan...
# 4    i m sorry i thought taiwan was an independent ...
# Name: clean_text, dtype: object

# %%
flattened_words_df = pd.DataFrame(
    [word for words_list in tweets_df.clean_text
    for word in words_list.split(' ')],
    columns=['word'])

flattened_words_df
# Out:
#             word
# 0           lets
# 1          focus
# 2             in
# 3            one
# 4           very
# ...          ...
# 421416      from
# 421417    taiwan
# 421418         s
# 421419  national
# 421420       che
#
# [421421 rows x 1 columns]

# %%
flattened_words_df.word.value_counts()[:20].plot(kind='bar')
plt.title('most frequent words')
plt.xlabel('words')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize=(20, 10))
plt.imshow(WordCloud(width=1000,height=600,stopwords=STOPWORDS).generate(' '.join(tweets_df.clean_text.values)))
plt.axis('off')
plt.title('Frequently Tweeted Words ',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Frequently Tweeted Words ')
